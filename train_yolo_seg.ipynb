# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
DATA_DIR = '/content/gdrive/My Drive/coding/yolov8_instance_seg/data/'

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 898.5/898.5 kB 24.6 MB/s eta 0:00:00
# ...

# %%
import os

from ultralytics import YOLO

model = YOLO('yolov8n-seg.pt')

model.train(data='/content/gdrive/My Drive/coding/yolov8_instance_seg/config.yaml', epochs=10, imgsz=640)
# Out:
# Ultralytics 8.3.40 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
import shutil
from google.colab import files

shutil.make_archive('/content/train', 'zip', '/content/runs/segment/train')

files.download('/content/train.zip')
